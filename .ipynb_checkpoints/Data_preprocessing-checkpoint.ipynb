# %% [markdown]
# ----
# # Loading [Amigos data][Amigos data] into numpy arrays
#
# ### Important labels:
# * VideoIDs
# * joined_data
# * labels_ext_annotation
# * labels_selfassessment
#
# [Amigos data]: <http://www.eecs.qmul.ac.uk/mmv/datasets/amigos/readme.html#prep>

# %%
import os
import sys
import scipy.io
import numpy as np
from tqdm import tqdm
from IPython.terminal.embed import InteractiveShellEmbed

ip_shell = InteractiveShellEmbed()
origin_path = ip_shell.magic("%pwd")

amigos_database_folder_name = "amigos"
amigos_folder = os.path.join(origin_path, amigos_database_folder_name)  # Folder that stores all amigos db data

preprocessed_data_folder = os.path.join(amigos_folder, "Data_Preprocessed")
preprocessed_data_files = [os.path.join(preprocessed_data_folder, name) for name
                            in os.listdir(preprocessed_data_folder) if name.split(".")[-1].lower() == "mat"]

# Loading data form files into list
data_to_preprocess = []
for index in tqdm(range(len(preprocessed_data_files))):
    file_path = preprocessed_data_files[index]  
    work_file = scipy.io.loadmat(file_path)
    data_to_preprocess.append(work_file)
    file_name = file_path.split('\\')[-1]

# Removal of non-valid data according to paper
ids_to_remove = [33, 24, 23, 22, 21, 12, 9]
for id_to_remove in ids_to_remove:
    data_to_preprocess.pop(id_to_remove)
# Out:
# 100%|██████████| 40/40 [00:18<00:00,  2.15it/s]

# %%
import numpy as np

patient_recorded_data = []
video_id_data = []
self_assesment_data = []
external_annotation_data = []
ECG_columns = [14, 15]

# Loading data into lists
for patient in data_to_preprocess:
    video_list = [video_id[0] for video_id in patient['VideoIDs'][0]]
    video_id_data.append(video_list)
    
    self_assesment = patient['labels_selfassessment'][0]
    self_assesment_matrix = np.zeros((len(self_assesment), len(self_assesment[0][0])), dtype=float)
    for row_index, video in enumerate(self_assesment):
        for col_index, value in enumerate(video[0]):
            self_assesment_matrix[row_index, col_index] = value
    self_assesment_data.append(self_assesment_matrix)
    
    external_annotation_data.append(list(patient['labels_ext_annotation'][0]))
    
    patient_recorded_data.append(list(patient['joined_data'][0]))
    
for pat_id, patient in enumerate(patient_recorded_data):
    videos_to_pop = [-1,-2,-3,-4] #last 4 videos are long videos we want to omit
    for index, video_ECG in enumerate(patient):
        if video_ECG.shape[0] == 0:
            videos_to_pop.append(index)
    
    if videos_to_pop:
        videos_to_pop.reverse()
        for video in videos_to_pop:
            patient.pop(video)
            print(f"Removing empty record \tPatient: {pat_id : >2} \tVideo: {video : >2}")

# Just ECG data
ECG_data = []
for patient in patient_recorded_data:
    patient_ECG = []
    for video in patient:
        patient_ECG.append(video[:, ECG_columns])
    ECG_data.append(patient_ECG)

# ECG_data = patient_recorded_data
# Out:
# Removing empty record 	Patient:  0 	Video: -4
# Removing empty record 	Patient:  0 	Video: -3
# Removing empty record 	Patient:  0 	Video: -2
# Removing empty record 	Patient:  0 	Video: -1
# Removing empty record 	Patient:  1 	Video: -4
# Removing empty record 	Patient:  1 	Video: -3
# Removing empty record 	Patient:  1 	Video: -2
# Removing empty record 	Patient:  1 	Video: -1
# Removing empty record 	Patient:  2 	Video: -4
# Removing empty record 	Patient:  2 	Video: -3
# Removing empty record 	Patient:  2 	Video: -2
# Removing empty record 	Patient:  2 	Video: -1
# Removing empty record 	Patient:  3 	Video: -4
# Removing empty record 	Patient:  3 	Video: -3
# Removing empty record 	Patient:  3 	Video: -2
# Removing empty record 	Patient:  3 	Video: -1
# Removing empty record 	Patient:  4 	Video: 19
# Removing empty record 	Patient:  4 	Video: 18
# Removing empty record 	Patient:  4 	Video: 17
# Removing empty record 	Patient:  4 	Video: 16
# Removing empty record 	Patient:  4 	Video: -4
# Removing empty record 	Patient:  4 	Video: -3
# Removing empty record 	Patient:  4 	Video: -2
# Removing empty record 	Patient:  4 	Video: -1
# Removing empty record 	Patient:  5 	Video: -4
# Removing empty record 	Patient:  5 	Video: -3
# Removing empty record 	Patient:  5 	Video: -2
# Removing empty record 	Patient:  5 	Video: -1
# Removing empty record 	Patient:  6 	Video: -4
# Removing empty record 	Patient:  6 	Video: -3
# Removing empty record 	Patient:  6 	Video: -2
# Removing empty record 	Patient:  6 	Video: -1
# Removing empty record 	Patient:  7 	Video: 19
# Removing empty record 	Patient:  7 	Video: 18
# Removing empty record 	Patient:  7 	Video: 17
# Removing empty record 	Patient:  7 	Video: 16
# Removing empty record 	Patient:  7 	Video: -4
# Removing empty record 	Patient:  7 	Video: -3
# Removing empty record 	Patient:  7 	Video: -2
# Removing empty record 	Patient:  7 	Video: -1
# Removing empty record 	Patient:  8 	Video: -4
# Removing empty record 	Patient:  8 	Video: -3
# Removing empty record 	Patient:  8 	Video: -2
# Removing empty record 	Patient:  8 	Video: -1
# Removing empty record 	Patient:  9 	Video: -4
# Removing empty record 	Patient:  9 	Video: -3
# Removing empty record 	Patient:  9 	Video: -2
# Removing empty record 	Patient:  9 	Video: -1
# Removing empty record 	Patient: 10 	Video: -4
# Removing empty record 	Patient: 10 	Video: -3
# Removing empty record 	Patient: 10 	Video: -2
# Removing empty record 	Patient: 10 	Video: -1
# Removing empty record 	Patient: 11 	Video: -4
# Removing empty record 	Patient: 11 	Video: -3
# Removing empty record 	Patient: 11 	Video: -2
# Removing empty record 	Patient: 11 	Video: -1
# Removing empty record 	Patient: 12 	Video: -4
# Removing empty record 	Patient: 12 	Video: -3
# Removing empty record 	Patient: 12 	Video: -2
# Removing empty record 	Patient: 12 	Video: -1
# Removing empty record 	Patient: 13 	Video: -4
# Removing empty record 	Patient: 13 	Video: -3
# Removing empty record 	Patient: 13 	Video: -2
# Removing empty record 	Patient: 13 	Video: -1
# Removing empty record 	Patient: 14 	Video: -4
# Removing empty record 	Patient: 14 	Video: -3
# Removing empty record 	Patient: 14 	Video: -2
# Removing empty record 	Patient: 14 	Video: -1
# Removing empty record 	Patient: 15 	Video: -4
# Removing empty record 	Patient: 15 	Video: -3
# Removing empty record 	Patient: 15 	Video: -2
# Removing empty record 	Patient: 15 	Video: -1
# Removing empty record 	Patient: 16 	Video: -4
# Removing empty record 	Patient: 16 	Video: -3
# Removing empty record 	Patient: 16 	Video: -2
# Removing empty record 	Patient: 16 	Video: -1
# Removing empty record 	Patient: 17 	Video: 19
# Removing empty record 	Patient: 17 	Video: 18
# Removing empty record 	Patient: 17 	Video: 17
# Removing empty record 	Patient: 17 	Video: 16
# Removing empty record 	Patient: 17 	Video: -4
# Removing empty record 	Patient: 17 	Video: -3
# Removing empty record 	Patient: 17 	Video: -2
# Removing empty record 	Patient: 17 	Video: -1
# Removing empty record 	Patient: 18 	Video: -4
# Removing empty record 	Patient: 18 	Video: -3
# Removing empty record 	Patient: 18 	Video: -2
# Removing empty record 	Patient: 18 	Video: -1
# Removing empty record 	Patient: 19 	Video: -4
# Removing empty record 	Patient: 19 	Video: -3
# Removing empty record 	Patient: 19 	Video: -2
# Removing empty record 	Patient: 19 	Video: -1
# Removing empty record 	Patient: 20 	Video: -4
# Removing empty record 	Patient: 20 	Video: -3
# Removing empty record 	Patient: 20 	Video: -2
# Removing empty record 	Patient: 20 	Video: -1
# Removing empty record 	Patient: 21 	Video: -4
# Removing empty record 	Patient: 21 	Video: -3
# Removing empty record 	Patient: 21 	Video: -2
# Removing empty record 	Patient: 21 	Video: -1
# Removing empty record 	Patient: 22 	Video: -4
# Removing empty record 	Patient: 22 	Video: -3
# Removing empty record 	Patient: 22 	Video: -2
# Removing empty record 	Patient: 22 	Video: -1
# Removing empty record 	Patient: 23 	Video: -4
# Removing empty record 	Patient: 23 	Video: -3
# Removing empty record 	Patient: 23 	Video: -2
# Removing empty record 	Patient: 23 	Video: -1
# Removing empty record 	Patient: 24 	Video: -4
# Removing empty record 	Patient: 24 	Video: -3
# Removing empty record 	Patient: 24 	Video: -2
# Removing empty record 	Patient: 24 	Video: -1
# Removing empty record 	Patient: 25 	Video: -4
# Removing empty record 	Patient: 25 	Video: -3
# Removing empty record 	Patient: 25 	Video: -2
# Removing empty record 	Patient: 25 	Video: -1
# Removing empty record 	Patient: 26 	Video: -4
# Removing empty record 	Patient: 26 	Video: -3
# Removing empty record 	Patient: 26 	Video: -2
# Removing empty record 	Patient: 26 	Video: -1
# Removing empty record 	Patient: 27 	Video: -4
# Removing empty record 	Patient: 27 	Video: -3
# Removing empty record 	Patient: 27 	Video: -2
# Removing empty record 	Patient: 27 	Video: -1
# Removing empty record 	Patient: 28 	Video: -4
# Removing empty record 	Patient: 28 	Video: -3
# Removing empty record 	Patient: 28 	Video: -2
# Removing empty record 	Patient: 28 	Video: -1
# Removing empty record 	Patient: 29 	Video: -4
# Removing empty record 	Patient: 29 	Video: -3
# Removing empty record 	Patient: 29 	Video: -2
# Removing empty record 	Patient: 29 	Video: -1
# Removing empty record 	Patient: 30 	Video: -4
# Removing empty record 	Patient: 30 	Video: -3
# Removing empty record 	Patient: 30 	Video: -2
# Removing empty record 	Patient: 30 	Video: -1
# Removing empty record 	Patient: 31 	Video: -4
# Removing empty record 	Patient: 31 	Video: -3
# Removing empty record 	Patient: 31 	Video: -2
# Removing empty record 	Patient: 31 	Video: -1
# Removing empty record 	Patient: 32 	Video: -4
# Removing empty record 	Patient: 32 	Video: -3
# Removing empty record 	Patient: 32 	Video: -2
# Removing empty record 	Patient: 32 	Video: -1

# %% [markdown]
# ----
# ## Data accessing
# * __video_id_data (a) (b)__ - _list of used videos (total of 20 elements)_
#     > a - patient ID
#
# * __self_assesment_data (a)__ - _matrix of 20 rows and 12 columns_
#     > a - patient ID
#
# * __external_annotation_data (a) (b)__ - _matrix of X1 rows and 3 columns_
#     > a - patient ID
#     > b - video sample index
#
# * __ECG_data (a) (b)__ - _matrix of X2 rows and 17 columns_
#     > a - patient ID
#     > b - video sample index

# %%
# Definition of functions
import math
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm
from sklearn.preprocessing import StandardScaler


def compare_two_ECG(data: list, patients=(0,1), time=(0,5), video=0, ECG=0, fig_size=(15,7),
                    sampling_frequency=128, colors=("b","r")):
    """
    Compares selected ECG data for two selected patiens
    
    :param data: ECG data list
    :param patients: tuple representing two selected patients
    :param time: tuple defineing start and end of the plot time axis
    :param video: selected video id
    :param ECG: selected ECG plot
    :param fig_size: size of the figure
    """
    
    sampling_frequency = 128
    patient_1 = data[patients[0]]
    patient_2 = data[patients[1]]
    
    X = np.arange(patient_1[video].shape[0])
    fig = plt.figure(figsize=fig_size)
    ax1 = fig.add_subplot(111)
    
    # Results for patient 1
    ax1.plot(X[time[0]*sampling_frequency:time[1]*sampling_frequency], 
             patient_1[video][:,ECG][time[0]*sampling_frequency:time[1]*sampling_frequency],
             color=colors[0], linewidth="0.75", label="Patient 1")
    
    # Results for patient 2
    ax1.plot(X[time[0]*sampling_frequency:time[1]*sampling_frequency], 
             patient_2[video][:,ECG][time[0]*sampling_frequency:time[1]*sampling_frequency],
             color=colors[1], linewidth="0.75", label="Patient 2")
    
    # Horizontal axis at y=0
    ax1.axhline(0, linewidth=1, color="k")
    plt.legend(fontsize=15)
    plt.show()
    

def compare_two_samples(data: list, patients=(0,1), time=(0,1), video=0, ECG=0, sample=0, fig_size=(15,7),
                    sampling_frequency=128, colors=("b","r")):
    """
    Compares selected sample ECG data for two selected patiens
    
    :param data: ECG data list
    :param patients: tuple representing two selected patients
    :param time: tuple defineing start and end of the plot time axis
    :param video: selected video id
    :param sample: number of ECG sample
    :param ECG: selected ECG plot
    :param fig_size: size of the figure
    """
    
    sampling_frequency = 128
    patient_1 = data[patients[0]]
    patient_2 = data[patients[1]]
    
    X = np.arange(patient_1[video][sample].shape[0])
    fig = plt.figure(figsize=fig_size)
    ax1 = fig.add_subplot(111)
    
    # Results for patient 1
    ax1.plot(X[time[0]*sampling_frequency:time[1]*sampling_frequency], 
             patient_1[video][sample][:,ECG][time[0]*sampling_frequency:time[1]*sampling_frequency],
             color=colors[0], linewidth="0.75", label="Patient 1")
    
    # Results for patient 2
    ax1.plot(X[time[0]*sampling_frequency:time[1]*sampling_frequency], 
             patient_2[video][sample][:,ECG][time[0]*sampling_frequency:time[1]*sampling_frequency],
             color=colors[1], linewidth="0.75", label="Patient 2")
    
    # Horizontal axis at y=0
    ax1.axhline(0, linewidth=1, color="k")
    plt.legend(fontsize=15)
    plt.show()
    
    
def plot_all_ECG_results(data: list, patient_ids=(0,), video=0, color=('r','b','g','c', 'y'), columns=2):
    """
    Draws plot comparasion for each patient listed in patient_ids
    
    :param data: ECG data list
    :param patient_ids: list of patient ids to plot from
    :param video: video selected for comparasion
    :param color: list of colors to be used
    :param columns: number of subplot columns
    :return: None
    """
    
    number_of_data_columns = len(data[patient_ids[0]][video][0])
    rows = math.ceil(number_of_data_columns/columns)  # Number of subplot rows
    fig, axs = plt.subplots(rows, columns, figsize=(8*columns, 3*rows))  # Generation of subplot
    
    for patient_number, patient_id in enumerate(patient_ids):
        ECG_records = data[patient_id]
        X = np.arange(ECG_records[video].shape[0])  # X axis vector

        for data_index in range(number_of_data_columns):
            if rows > 1:
                axs[data_index//columns, data_index%columns].plot(X, ECG_records[video][:,data_index],
                                                                    color=color[patient_number], linewidth='0.75', 
                                                                    label=f"patient {patient_id}")  # Plot recorded values
                axs[data_index//columns, data_index%columns].axhline(0, linewidth=1, color='k')  # Horizontal line at y=0
            else:
                axs[data_index%columns].plot(X, ECG_records[video][:,data_index],
                                                                    color=color[patient_number], linewidth='0.75', 
                                                                    label=f"patient {patient_id}")  # Plot recorded values
                axs[data_index%columns].axhline(0, linewidth=1, color='k')  # Horizontal line at y=0

    # Remove empty plots
    if rows > 1:
        subplot_axes = [value for row in axs for value in row]  # List of all axes

        # Select only empty axes
        for ax in [value for index, value in enumerate(subplot_axes) if index >= number_of_data_columns]: 
            ax.remove()  # don't display empty axes

        handles, labels = axs[0, 0].get_legend_handles_labels()
        fig.legend(handles, labels, loc='lower center', fontsize=25)

    else:
        subplot_axes = [value for value in axs]  # List of all axes

        # Select only empty axes
        for ax in [value for index, value in enumerate(subplot_axes) if index >= number_of_data_columns]: 
            ax.remove()  # don't display empty axes

        handles, labels = axs[0].get_legend_handles_labels()
        fig.legend(handles, labels, loc='center right', fontsize=12)

    plt.show()
    
    
def trim_data(data: list, start_trim=2, end_trim=2, sampling_frequency=128) -> list:
    """
    Trims ECG data by given trim times
    
    :param data: ECG data list
    :param start_trim: time to be removed from the begginig of the data series in seconds
    :param end_trim: time to be removed from the end of the data series in seconds
    :param sampling_frequency: sampling frequency in Hz
    :return: trimed ECG data in list
    """
    
    trimmed_data = []
    for current_patient in data:
        video_data = []
        for current_video in current_patient:
            start_time = sampling_frequency * start_trim
            end_time = current_video.shape[0] - sampling_frequency * end_trim
            video_data.append(current_video[start_time:end_time])
        trimmed_data.append(video_data)
    return trimmed_data


def extract_data(data: list, start_time = 0, extract_time = 5, sampling_frequency=128) -> list:
    """
    Extract data from ECG data by given start time and time window
    
    :param data: ECG data list
    :param start_time: start time in seconds
    :param end_trim: number seconds to be extracted from data
    :param sampling_frequency: sampling frequency in Hz
    :return: list of extracted ECG data
    """
    
    extracted_data = []
    for current_patient in data:
        video_data = []
        for current_video in current_patient:
            start = int(start_time*sampling_frequency)
            end = int(start_time + sampling_frequency * extract_time)
            video_data.append(current_video[start:end,:])
        extracted_data.append(video_data)
    return extracted_data


def calculate_mean_over_data(data: list, calculation_frequency=1, sampling_frequency=128) -> list:
    """
    Calculates mean over data for given calculation frequency [seconds] and sampling frequency [Hz]
    :param data: ECG data list
    :param calculation_frequency: time window over which mean is calculated
    :param sampling_frequency: number of samples taken per second
    :return: averaged by given criteria ECG data list
    """
    
    calculated_baseline = []
    for current_patient in data:
        video_data = []
        for current_video in current_patient:
            number_of_splits = current_video.shape[0] // (sampling_frequency * calculation_frequency)
            split_positions = [(pos+1)*calculation_frequency*sampling_frequency for pos in range(number_of_splits)]
            current_data = np.split(current_video, split_positions)

            if current_data[-1].shape[0] == 0:  # Remove last row of splitted array if it's empty
                current_data.pop(len(current_data)-1)
            
            sample_data = []
            for sample in current_data:
                sample_data.append(np.mean(sample, axis=0))
                
            video_data.append(np.array(sample_data))
            
        calculated_baseline.append(video_data)   
    return calculated_baseline


def calculate_mean_baseline(data: list) -> list:
    """
    Calculates mean ECG signal from all the samples
    
    :param data: baseline ECG data list
    :return: single sample list of ECG data
    """
    
    splited_data = split_data_into_samples(data, sample_length=1)
    calculated_baseline_mean = []
    for patient in splited_data:
        video_data = []
        for video in patient:
            sample_data = np.zeros(video[0].shape, dtype=float)
            for sample in video:
                sample_data = np.add(sample_data, sample)
            video_data.append(sample_data)
        calculated_baseline_mean.append(video_data)
    return calculated_baseline_mean
            

def subtract_baseline_data(data: list, baseline_data:list) -> list:
    """
    Subtract baseline data from all corresponding elements of ECG data
    
    :param data: ECG data list
    :param baseline_data: list of baseline readings of ECG data size
    :return: ECG data list subtracted by corresponding baseline readings 
    """
    
    new_data = []
    for patient_index, patient in enumerate(data):
        video_data = []
        for video_index, video in enumerate(patient):
            sample_data = []
            for sample in video:
                sample_data.append(sample - baseline_data[patient_index][video_index][:sample.shape[0],:])
            video_data.append(sample_data)
        new_data.append(video_data)
    return new_data
    
    
def generate_baseline_subtraction_matrix(baseline_data: np.ndarray, size: tuple) -> np.ndarray:
    """
    Generates baseline matrix of the given shape by repeating baseline_data rows
    
    :param baseline_data: list of baseline reading from ECG_data
    :param size: tuple defining shape of output matrix
    :return: matrix of predefined sized
    """
    
    base_rows = baseline_data.shape[0]
    target_rows = size[0]
    repetitions = math.ceil(target_rows / base_rows)
    repetition_matrix = np.tile(baseline_data, (repetitions,1))
    return_matrix = repetition_matrix[:size[0], :size[1]]
    return return_matrix


def subtract_baseline_from_data(data: list, baseline: list) -> list:
    """
    Subtracts baseline reading from ECG reading
    
    :param data: ECG data list
    :param baseline: matrix of baseline readings of ECG data size
    :return: ECG data list subtracted by corresponding baseline readings 
    """
        
    new_data = []
    for patient_index, current_patient in enumerate(data):
        video_data = []
        for video_index, current_video in enumerate(current_patient):
            baseline_subtract = generate_baseline_subtraction_matrix(baseline[patient_index][video_index], 
                                                                 size=current_video.shape)
            video_data.append(current_video - baseline_subtract)
        new_data.append(video_data)
    return new_data


def split_data_into_samples(data: list, sample_length=1, sampling_frequency=128) -> list:
    """
    Split data int samples of specified length
    
    :param data: ECG data list
    :param sample_length: length of sample to use in seconds
    :param sampling_frequency: number of samples taken per second
    :return: list of samples taken from ECG data list
    """
    
    new_data = []
    for patient in data:
        video_data = []
        for video in patient:
            
            split_positions = [(pos+1)*sample_length*sampling_frequency for pos in range(
                video.shape[0] // (sampling_frequency * sample_length))]
            splited_data = np.split(video, split_positions)
            
            if splited_data[-1].shape[0] == 0:  # Remove last row of splitted array if it's empty
                splited_data.pop(len(splited_data)-1)  
            video_data.append(splited_data)
        new_data.append(video_data)
    return new_data
            

def zscore_normalize_data(data: list) -> list:
    """
    Performs zscale on the given ECG data
    
    :param data: ECG data list
    :return: Scaled ECG data list
    """
    
    # scaler = StandardScaler()
    new_data = []
    for index in tqdm(range(len(data))):
        patient = data[index]
        video_data = []
        for video in patient:
            sample_data = []
            for sample in video:
                u = np.mean(sample, axis=0)
                s = np.std(sample, axis=0)
                sample_data.append((sample - u ) / s)
                # Sklearn StandradScaler crashed on this data dunno why :(
                # transposed_sample = np.transpose(sample)
                # scaler.fit(list(transposed_sample))
                # sample_data.append(np.transpose(scaler.transform(transposed_sample)))
            video_data.append(sample_data)
        new_data.append(video_data)
    return new_data


def downsize_sample(data: list, sample_size: float) -> list:
    """
    Reduces the number of samples in data to smallest one chosing samples by predefined step size
    """
    return_data = []
    for patient in data:
        patient_data = []
        for item in patient:
            sample_size = smallest_sample
            step = item.shape[0] / smallest_sample
            index_array = np.arange(item.shape[0])
            truth_table =(index_array[:-1] // step) != (index_array[1:] // step)
            final_truths = np.append(np.array([True]), truth_table, axis=0)
            patient_data.append(item[final_truths,:])
        return_data.append(patient_data)
    return return_data

# %%
print(len(ECG_data[0]))
print(ECG_data[1][0].shape)
# Out:
# 16
# (12225, 2)

# %% [markdown]
# ----
# # Data presentation for patient

# %%
plot_all_ECG_results(ECG_data, patient_ids=(1,5,18))

# %%
compare_two_ECG(ECG_data, patients=(3,6), time=(0,10), video=4, ECG=0)

# %%
extracted_data = extract_data(data=ECG_data, extract_time = 5)
baseline_data = calculate_mean_over_data(data=extracted_data)
trimmed_data = trim_data(data=ECG_data, start_trim=7)
trimmed_mean_data = calculate_mean_over_data(data=trimmed_data, calculation_frequency=1)
subtracted_data = subtract_baseline_from_data(data=trimmed_mean_data, baseline=baseline_data)
# scaled_data = zscore_normalize_data(data=subtracted_data)

# %%
plot_all_ECG_results(subtracted_data, patient_ids=(1,5,18))

# %%
compare_two_ECG(subtracted_data, patients=(3,6), time=(0,60), video=4, ECG=1, colors=("r", "g"))

# %%
# Baseline data processing
extracted_data = extract_data(data=ECG_data, extract_time = 5)
baseline_data = calculate_mean_baseline(data=extracted_data)

# ECG main data processing
trimed_data = trim_data(data=ECG_data, start_trim=7)

# Scaling all movies to the same length
videos_to_remove = [15, 14 ,13 ,12]
for patient in trimed_data:
    for video_number in videos_to_remove:
        if len(patient) > 12:
            patient.pop(video_number)
smallest_sample = min([item.shape[0] for item in trimed_data[0]])
trimed_data = downsize_sample(trimed_data, smallest_sample)

# ECG main data processing
splited_data = split_data_into_samples(data=trimed_data, sample_length=1)
del trimed_data
nobaseline_data = subtract_baseline_data(data=splited_data, baseline_data=baseline_data)
del splited_data
normalized_data = zscore_normalize_data(data=nobaseline_data)
# Out:
# 100%|██████████| 33/33 [00:00<00:00, 53.28it/s]

# %%
compare_two_samples(nobaseline_data, patients=(1,18), time=(0,1), video=4, ECG=0, sample=6, colors=("r", "g"))

# %%
compare_two_samples(normalized_data, patients=(1,18), time=(0,1), video=4, ECG=0, sample=6, colors=("r", "g"))

# %% [markdown]
# # Store data in input and output arrays for neural network

# %%
#In the paper there are distinguished 4 classes and each samples belongs to one of them: 
#HVHA,HVLA,LVHA,LVLA (low,high,valence,arousal)

def assignTargetClass(y):
    output = np.array([1.,1.,1.,1.],dtype="float32")
    
    #valence:
    if y[0]<4.5:
        output *= [0.,0.,1.,1.] #Low valence
    else:
        output *= [1.,1.,0.,0.] #High valence
        
    #arousal:
    if y[1]<4.5:
        output *= [0.,1.,0.,1.] #Low arousal
    else:
        output *= [1.,0.,1.,0.] #High arousal
 
    return output

# %% [markdown]
# In order to feed neural network with input data, first our multi-level data structure has to be flattened into fixed size arrays.

# %%
x = np.empty((0,48,128,2))
y = []
counter = 0
for i,patient in tqdm(enumerate(normalized_data)):
    for j,sample in enumerate(patient):
        
        a = np.empty((0,128,2))
        for b in normalized_data[i][j]:
            fin = b.copy()
            if len(b)<128:
                fin.resize((128,2)) #zero pad at the end
                
            a = np.append(a,np.array([fin]),axis=0)
            
        y.append(assignTargetClass(self_assesment_data[i][j]))
        x = np.append(x,np.array([a]),axis=0)
        counter +=1
x.shape
# Out:
# 33it [00:00, 35.47it/s]
# (396, 48, 128, 2)

# %%
#limit to single ECG channel [:,:,:,0]
x = x[:,:,:,0].reshape((396,48,128,1))
x.shape
# Out:
# (396, 48, 128, 1)

# %%
#lets take a look at output class distribution:
fig = plt.figure(figsize=(15,5))
axs = fig.add_subplot(111)
axs.bar(["HVHA","HVLA","LVHA","LVLA"], height=sum(y))
axs.set_title('Output class distribution')
# Out:
# Text(0.5, 1.0, 'Output class distribution')

# %%
#https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly
import keras

class DataGenerator(keras.utils.Sequence):
    
    def __init__(self, list_IDs, labels, batch_size=32, dim=(48,128), n_channels=1,
             n_classes=4, shuffle=True):
    
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()
        
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
    
    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        
        #get sample will return list of lists of values i.e. seconds*128
        
        X = np.empty((self.batch_size, *self.dim, self.n_channels),dtype=float)
        Y = np.empty((self.batch_size,self.n_classes), dtype=int)
        # Generate data
        for i, ID in enumerate(list_IDs_temp):
          # Store sample
          X[i] = x[ID]
          # Store class
          Y[i] = y[ID]

        return X, Y
    
    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))
    
    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        # Generate data
        X, Y = self.__data_generation(list_IDs_temp)

        return X, Y

# %%
from sklearn.model_selection import train_test_split

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size=0.3, shuffle=True)
x_validation, x_test, y_validation, y_test = train_test_split(x_validation,y_validation,test_size=0.5,shuffle=True)

# training_generator = DataGenerator(range(0,len(x_train)),y_train,batch_size=batch_size,dim=(48,128),n_channels=1)
# validation_generator = DataGenerator(range(0,len(x_validation)),y_validation,batch_size=batch_size,dim=(48,128),n_channels=1)
# test_generator = DataGenerator(range(0,len(x_test)),y_test,batch_size=batch_size,dim=(48,128),n_channels=1)

# %%
print(x_train.shape)
print(x_validation.shape)
print(x_test.shape)
# Out:
# (277, 48, 128, 1)
# (59, 48, 128, 1)
# (60, 48, 128, 1)

# %%
import tensorflow as tf
from keras import models
from keras import layers
from keras import optimizers

#required to run on my GPU

# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.experimental.set_virtual_device_configuration(
#         gpus[0],
#         [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
#     logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# %% [markdown]
# # Problem
# it's possible to replicate structure presented in the paper however layer folding layer is unique to matlab and replicating it may be hard to do.
# Initial idea is to replace conv1d with conv 2d and supply model with all samples.

# %%
import tensorflow as tf
from keras import models
from keras import layers
from keras import optimizers
inputs = keras.Input(shape=(128,1))
conv_layer_1 = layers.Conv1D(16, 3, activation="relu", padding="same")(inputs)
pool_layer_1 = layers.MaxPooling1D(2, 1, padding="same")(conv_layer_1)
conv_layer_2 = layers.Conv1D(32, 3, activation="relu", padding="same")(pool_layer_1)
pool_layer_2 = layers.MaxPooling1D(2, 1, padding="same")(conv_layer_2)
merged_io_layer_1 = layers.Concatenate(axis=2)([pool_layer_2, inputs])
flatten_layer_1 = layers.Flatten()(merged_io_layer_1)
lstm_input_layer_1 = layers.Reshape((-1,1))(flatten_layer_1)
lstm_layer = layers.LSTM(128,activation="tanh",recurrent_activation="sigmoid")(lstm_input_layer_1)
dense_layer_1 = layers.Dense(256, activation='relu')(lstm_layer)
dropout_layer_1 = layers.Dropout(0.5)(dense_layer_1)
dense_layer_2 = layers.Dense(128, activation='relu')(dropout_layer_1)
dropout_layer_2 = layers.Dropout(0.5)(dense_layer_2)
dense_layer_3 = layers.Dense(4, activation='relu')(dropout_layer_2)
dropout_layer_3 = layers.Dropout(0.5)(dense_layer_3)
outputs = layers.Activation("softmax")(dropout_layer_3)
model = keras.Model(inputs=inputs, outputs=outputs, name="mnist_model")
model.summary()
# Out:
# Model: "mnist_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 128, 16)      64          input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 128, 16)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 128, 32)      1568        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 128, 32)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 33)      0           max_pooling1d_1[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4224)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 4224, 1)      0           flatten[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 128)          66560       reshape[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          33024       lstm[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          32896       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4)            516         dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 4)            0           dense_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 4)            0           dropout_2[0][0]
# ==================================================================================================
# Total params: 134,628
# Trainable params: 134,628
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from keras import models
from keras import layers
from keras import optimizers
inputs = keras.Input(shape=(47,128,1))
conv_layer_1 = layers.Conv2D(16, 3, activation="relu", padding="same")(inputs)
pool_layer_1 = layers.MaxPooling2D(2, 1, padding="same")(conv_layer_1)
conv_layer_2 = layers.Conv2D(32, 3, activation="relu", padding="same")(pool_layer_1)
pool_layer_2 = layers.MaxPooling2D(2, 1, padding="same")(conv_layer_2)
shape = pool_layer_2.get_shape().as_list()
sequence_unfolding_layer_1 = layers.Reshape((shape[1],shape[2]*shape[3]))(pool_layer_2)
print(sequence_unfolding_layer_1.get_shape())
lstm_layer = layers.LSTM(128,activation="tanh",recurrent_activation="sigmoid")(sequence_unfolding_layer_1)
dense_layer_1 = layers.Dense(256, activation='relu')(lstm_layer)
dropout_layer_1 = layers.Dropout(0.5)(dense_layer_1)
dense_layer_2 = layers.Dense(128, activation='relu')(dropout_layer_1)
dropout_layer_2 = layers.Dropout(0.5)(dense_layer_2)
dense_layer_3 = layers.Dense(4, activation='relu')(dropout_layer_2)
dropout_layer_3 = layers.Dropout(0.5)(dense_layer_3)
outputs = layers.Activation("softmax")(dropout_layer_3)
model = keras.Model(inputs=inputs, outputs=outputs, name="mnist_model")
model.summary()
# Out:
# (None, 47, 4096)
# Model: "mnist_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 47, 128, 1)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 47, 128, 16)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 47, 128, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 47, 128, 32)       4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 128, 32)       0
# _________________________________________________________________
# reshape_9 (Reshape)          (None, 47, 4096)          0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 128)               2163200
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 516
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# activation_2 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 2,234,436
# Trainable params: 2,234,436
# Non-trainable params: 0
# _________________________________________________________________

# %%
shape_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-38ea9326578b> in <module>
# ----> 1 shape_2
#
# NameError: name 'shape_2' is not defined

# %%
# from keras import models
# from keras import layers
# from keras import optimizers
def getCustomModel():
    model = models.Sequential()
    #in original paper some 'folding here'
    # Most likely input shape will be (N,128,1) where N=47 (nuber of samples in single video)
    def convSubNet():
        subModel = models.Sequential()
        subModel.add(layers.Conv1D(16, 3, activation='relu', padding="same", input_shape=(128,1)))
        subModel.add(layers.MaxPooling1D(2, 1, padding="same"))
#         subModel.add(layers.Dropout(0.3))
        subModel.add(layers.Conv1D(32, 3, activation='relu', padding="same"))
        subModel.add(layers.MaxPooling1D(2, 1, padding="same"))
#         subModel.add(layers.Dropout(0.3))
        return subModel

    inputs = keras.Input(shape=(48,128,1))
    time_distributed_layer = layers.TimeDistributed(convSubNet())(inputs) 
    shape = time_distributed_layer.get_shape().as_list()

    reshaped_layer = layers.Reshape((shape[1],shape[2]*shape[3]))(time_distributed_layer)
    # model.add(layers.Flatten())
    print(reshaped_layer.get_shape())
    l2 = layers.LSTM(128,activation="tanh",recurrent_activation="sigmoid")(reshaped_layer)
    l3 = layers.Dense(256, activation='relu')(l2)
    l4 = layers.Dropout(0.5)(l3)
    l5 = layers.Dense(128, activation='relu')(l4)
    l6 = layers.Dropout(0.5)(l5)
    l7 = layers.Dense(4, activation='relu')(l6)
    l8 = layers.Dropout(0.5)(l7)
    outputs = layers.Activation('softmax')(l8)
    return keras.Model(inputs=inputs, outputs=outputs, name="dev-workshop-model")
    
getCustomModel().summary()
# Out:
# (None, 48, 4096)
# Model: "dev-workshop-model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 48, 128, 1)]      0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 48, 128, 32)       1632
# _________________________________________________________________
# reshape_6 (Reshape)          (None, 48, 4096)          0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 128)               2163200
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 516
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 4)                 0
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 2,231,268
# Trainable params: 2,231,268
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Out:
# 42

# %%
batch_size = 16
model = getCustomModel()
model.compile(optimizer=optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0
100
# 17/17 [==============================] - 0s 18ms/step - loss: 1.1190 - acc: 0.4628 - val_loss: 1.7305 - val_acc: 0.2542
# Epoch 94/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.9898 - acc: 0.5315 - val_loss: 1.8482 - val_acc: 0.2373
# Epoch 95/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.9378 - acc: 0.4821 - val_loss: 1.9939 - val_acc: 0.2542
# Epoch 96/100
# 17/17 [==============================] - 0s 19ms/step - loss: 1.0059 - acc: 0.5146 - val_loss: 1.9373 - val_acc: 0.2542
# Epoch 97/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.9825 - acc: 0.4988 - val_loss: 1.9388 - val_acc: 0.2881
# Epoch 98/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.9861 - acc: 0.4824 - val_loss: 1.6940 - val_acc: 0.2712
# Epoch 99/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.9451 - acc: 0.5086 - val_loss: 1.7415 - val_acc: 0.2373
# Epoch 100/100
# 17/17 [==============================] - 0s 18ms/step - loss: 1.0399 - acc: 0.4973 - val_loss: 1.9207 - val_acc: 0.2542

# %%
def PlotLoss(loss,val_loss):
    fig = plt.figure(figsize=(15,5))
    axs = fig.add_subplot(111)
    axs.plot(loss,'bo',label="Training loss")
    axs.plot(val_loss,'b',label="Validation loss")
    axs.legend(["Training loss","Validation loss"], loc='lower center')
    axs.set_title('Loss')

def PlotAccuracy(acc,val_acc):
    fig = plt.figure(figsize=(15,5))
    axs = fig.add_subplot(111)
    axs.plot(acc,'ro',label="Training accuracy")
    axs.plot(val_acc,'r',label="Validation accuracy")
    axs.legend(["Training accuracy","Validation accuracy"], loc='lower center')
    axs.set_title('Accuracy')
    
PlotLoss(history.history["loss"],history.history["val_loss"])
PlotAccuracy(history.history["acc"],history.history["val_acc"])

# %%
model.evaluate(x=x_test,y=np.array(y_test))
# Out:
# 2/2 [==============================] - 0s 103ms/step - loss: 2.5437 - acc: 0.3500
# [2.543729066848755, 0.3499999940395355]

# %% [markdown]
# So at this point I can't belive we achieved 100% val accuracy so I'll check why is that - class distribution and k-fold cross validation.

# %%
fig = plt.figure(figsize=(15,5))
axs = fig.add_subplot(111)
axs.bar(["HVHA","HVLA","LVHA","LVLA"], height=sum(y_train))
axs.set_title('Training class distribution')
# Out:
# Text(0.5, 1.0, 'Training class distribution')

# %%
fig = plt.figure(figsize=(15,5))
axs = fig.add_subplot(111)
axs.bar(["HVHA","HVLA","LVHA","LVLA"], height=sum(y_test))
axs.set_title('Test class distribution')
# Out:
# Text(0.5, 1.0, 'Test class distribution')

# %%
# Out:
# (366, 4)

# %%
from sklearn.model_selection import KFold
folds = 10
kf = KFold(n_splits=folds,shuffle=True)
histories = []
evaluations = []
#merge train and validation to perform k-fold cross validation
#keep previous test set separated for evaluation
splitSetX = np.append(x_train,x_validation,axis=0)
splitSetY = np.append(y_train,y_validation,axis=0)

for count,(train_index, test_index) in enumerate(kf.split(splitSetX)):
    print("Fold: ", count)
    x_train_folded, x_test_folded = splitSetX[train_index], splitSetX[test_index]
    y_train_folded, y_test_folded = splitSetY[train_index], splitSetY[test_index]
    
    model = getCustomModel() #get clean model
    model.compile(optimizer=optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0
100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.8657 - acc: 0.5232 - val_loss: 2.8001 - val_acc: 0.2121
# Epoch 96/100
# 18/18 [==============================] - 0s 16ms/step - loss: 0.8418 - acc: 0.5274 - val_loss: 2.6738 - val_acc: 0.1818
# Epoch 97/100
# 18/18 [==============================] - 0s 16ms/step - loss: 0.8029 - acc: 0.5523 - val_loss: 2.7324 - val_acc: 0.1818
# Epoch 98/100
# 18/18 [==============================] - 0s 16ms/step - loss: 0.7319 - acc: 0.5796 - val_loss: 2.6440 - val_acc: 0.2121
# Epoch 99/100
# 18/18 [==============================] - 0s 16ms/step - loss: 0.7718 - acc: 0.5426 - val_loss: 2.6934 - val_acc: 0.2424
# Epoch 100/100
# 18/18 [==============================] - 0s 17ms/step - loss: 0.8258 - acc: 0.5100 - val_loss: 3.1286 - val_acc: 0.2424
# 2/2 [==============================] - 0s 9ms/step - loss: 2.8367 - acc: 0.2833

# %%
print([history.history["val_acc"][-1] for history in histories])
print("Mean train acc:",np.mean([history.history["acc"][-1] for history in histories]))
print("Mean val acc:",np.mean([history.history["val_acc"][-1] for history in histories]))
print("Mean evaluation acc:",np.mean([evaluation[1] for evaluation in evaluations]))
# Out:
# [0.23529411852359772, 0.3529411852359772, 0.20588235557079315, 0.1764705926179886, 0.23529411852359772, 0.2647058963775635, 0.24242424964904785, 0.3636363744735718, 0.27272728085517883, 0.24242424964904785]
# Mean train acc: 0.47238006740808486
# Mean val acc: 0.2591800421476364
# Mean evaluation acc: 0.2816666647791862

# %%
# Out:
# [1.3862942457199097, 0.21666666865348816]

# %%
fig = plt.figure(figsize=(15,5))
axs = fig.add_subplot(111)
for history in histories:
    axs.plot(history.history["val_acc"])
axs.set_title('Validation accuracies')
# Out:
# Text(0.5, 1.0, 'Validation accuracies')

# %%
fig = plt.figure(figsize=(15,5))
axs = fig.add_subplot(111)
for history in histories:
    axs.plot(history.history["val_loss"])
axs.set_title('Training val losses')
# Out:
# Text(0.5, 1.0, 'Training val losses')

# %% [markdown]
# # TO DO:
# * ~~Remove first and last 2 seconds of the recording~~
# * ~~Create baseline mean for the data (guess it's first 5 seconds of the video)~~
# * ~~Subtract baseline recursively?? i guess by the pdf from the measurements~~
# * ~~Z-score normalization~~ (average over sample or population?)
# * create working NN
# * train

# %% [markdown]
# model = models.Sequential()
# #in original paper some 'folding here'
# #Most likely input shape will be (N,128,1) where N=47 (nuber of samples in single video)
# model.add(layers.Conv1D(16, 3, activation='relu',padding="same", input_shape=(128,1)))
# model.add(layers.MaxPooling1D(2,1,padding="same",))
# model.add(layers.Conv1D(32, 3, activation='relu',padding="same"))
# model.add(layers.MaxPooling1D(2,1,padding="same"))
# #in original paper some 'unfolding here'
# model.add(layers.Flatten())
# model.add(layers.Reshape((-1,1)))
# model.add(layers.LSTM(128,activation="tanh",recurrent_activation="sigmoid"))
# model.add(layers.Dense(256, activation='relu'))
# model.add(layers.Dropout(0.5))
# model.add(layers.Dense(128, activation='relu'))
# model.add(layers.Dropout(0.5))
# model.add(layers.Dense(4, activation='relu'))
# model.add(layers.Dropout(0.5))
# model.add(layers.Activation('softmax'))
# model.summary()

# %% [markdown]
# model.compile(optimizer=optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.99),
#               loss='categorical_crossentropy',
#               metrics=['acc'])
#
#
# history = model.fit(training_generator,
#                     epochs=50,
#                     validation_data=validation_generator)
